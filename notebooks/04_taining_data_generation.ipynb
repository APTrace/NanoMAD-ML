# %%
# %pwd
# Out:
# '/gpfs/easy/data/id01/inhouse/tsarrazin/Concentration/NanoMAD ML/Phase6/Phase_6.0'

# %%
# =============================================================================
# GENERATE 5000 TRAINING PARTICLES
# =============================================================================

# Set your output directory here (use raw string r"..." for Windows paths)
output_dir = r"/data/id01/inhouse/tsarrazin/Concentration/NanoMAD ML/synthetic_data/test3__6.0_1e6scale_5000"  # <-- CHANGE THIS to your desired path

# Generate the dataset
# !python generate_training_data.py -n 5000 -o "{output_dir}" --sf-dir . --seed 42

# %%
# =============================================================================
# GENERATE 100 TRAINING PARTICLES WITH PATCH OVERLAP
# =============================================================================

# Set your output directory here (use raw string r"..." for Windows paths)
output_dir = r"/data/id01/inhouse/tsarrazin/Concentration/NanoMAD ML/synthetic_data/test4__6.0_1e6scale_overlap_500" 

# 50% overlap (stride=8, ~225 patches per particle)
# !python generate_training_data.py -n 500 -o "{output_dir}" --sf-dir . --overlap --stride 8
# Out:
# ...
# NANOMAD TRAINING DATA GENERATION
# ...
#
# Output directory: /data/id01/inhouse/tsarrazin/Concentration/NanoMAD ML/synthetic_data/test4__6.0_1e6scale_overlap_2000
# Random seed: 42
#
# Loading scattering factors from: .
# Loading scattering factors for Ni from Nickel.f1f2...
#   Loaded 4601 data points
#   Energy range: 2000.0 - 25000.0 eV
# Loading scattering factors for Fe from Iron.f1f2...
#   Loaded 4601 data points
#   Energy range: 2000.0 - 25000.0 eV
#
# ------------------------------------------------------------------------------
# CONFIGURATION
# ------------------------------------------------------------------------------
#   Particles to generate: 500
#   FFT grid size: 256 × 256
#   Output grid size: 128 × 128
#   Patch size: 16 × 16
#   Overlapping patches: ON (stride=8, 50% overlap)
#   Patches per particle: 225
#   Energies: 8 (8313 - 8348 eV)
#   Module noise: ON
#   Poisson noise: ON
#
#   Shape distribution:
#     hexagon: 30%
#     polygon: 20%
# ...
